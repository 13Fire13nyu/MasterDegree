# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow import keras
from IPython import display


import fnmatch

# Set seed for experiment reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
data_dir = pathlib.Path(r"D:\magistracy\diplom\records_cut")
filenames = []
for root, dirs, files in os.walk(data_dir):
    for file in files:
        if(file.endswith(".wav")):
            filenames.append(os.path.join(root,file))

# %%
notes = np.array(tf.io.gfile.listdir(str(data_dir)))
print('Notes:', notes)
# Out:
# Notes: ['A' 'A#' 'B' 'C' 'C#' 'D' 'D#' 'E' 'F' 'F#' 'G' 'G#']

# %%
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/notes[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 30828
# Number of examples per label: 2318
# Example file tensor: tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\D#\\en027a_55.wav', shape=(), dtype=string)

# %%
# Для удобства разбиения выборки на тренировочную, тестовую и валидационную возьмем только 28000 файлов, 
# которые разобьем в соотношении 70:20:10 

filenames = filenames[:28000]

train_files = filenames[:19600]
val_files = filenames[19600: 19600 + 5600]
test_files = filenames[-2800:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 19600
# Validation set size 5600
# Test set size 2800

# %%
# После разделения изначальных аудио-файлов на ноты все получившиеся записи стали моно-записями
test_file = tf.io.read_file(filenames[0])
test_audio, _ = tf.audio.decode_wav(contents=test_file)
test_audio.shape
# Out:
# TensorShape([11506, 1])

# %%
def decode_audio(audio_binary):
    audio, _ = tf.audio.decode_wav(audio_binary) # возвращает WAV-кодированные как Тензор и частотой дискретизации.
    return tf.squeeze(audio, axis=-1)

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    # Примечание. Здесь будет использоваться индексирование вместо распаковки кортежей, 
    # чтобы это работало на графике TensorFlow.
    return parts[-2]

def get_waveform_and_label(file_path):
    label = get_label(file_path)
    audio_binary = tf.io.read_file(file_path)
    waveform = decode_audio(audio_binary)
    return waveform, label

def without_zero_len(waveform, label):
    if len(waveform)!=0:  
        return True
    return False

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
count = 0
for a,_ in waveform_ds:
    count+=1
    if a.shape[0]==0:
        print(count, filenames[count])
waveform_ds = waveform_ds.filter(without_zero_len) # Удаляем сигналы нулевой длины
# Out:
# 1171 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\G\\en045a_5.wav', shape=(), dtype=string)
# 2199 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\G\\en022b_76.wav', shape=(), dtype=string)
# 4355 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\F#\\en049a_84.wav', shape=(), dtype=string)
# 4425 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\E\\kr021b_42.wav', shape=(), dtype=string)
# 8201 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\F#\\kr002b_204.wav', shape=(), dtype=string)
# 9690 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\D#\\kr038b_134.wav', shape=(), dtype=string)
# 12707 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\D\\kr019a_8.wav', shape=(), dtype=string)
# 14965 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\F#\\en012b_80.wav', shape=(), dtype=string)
# 17485 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\C#\\kr005b_65.wav', shape=(), dtype=string)
# 19349 tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\G\\en031a_54.wav', shape=(), dtype=string)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
for i, (audio, label) in enumerate(waveform_ds.take(n)):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    ax.plot(audio.numpy())
    ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
    label = label.numpy().decode('utf-8')
    ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
    
    input_len = 1025*15
    waveform = waveform[:input_len]
    # Заполнение нулями для файлов с длиной, меньше input_len
    #zero_padding = tf.zeros([1024*15] - tf.shape(waveform), dtype=tf.float32)
    # Объедините звук с заполнением, чтобы все аудиоклипы были одинаковой длины.
    waveform = tf.cast(waveform, tf.float32)
    #equal_length = tf.concat([waveform, zero_padding], 0)
    equal_length = waveform
    spectrogram = tf.signal.stft(equal_length, frame_length=2048, frame_step=1024,pad_end=True)
    spectrogram = tf.abs(spectrogram)

    return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
    label = label.numpy().decode('utf-8')
    spectrogram = get_spectrogram(waveform) 

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=44100))
# Out:
# Label: D#
# Waveform shape: (11506,)
# Spectrogram shape: (12, 1025)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
    # Преобразуем в частоты для логарифмической шкалы и транспонируем так, чтобы время
    # было представлено на оси x (столбцы). Эпсилон добавляется, чтобы избежать нуля.
    log_spec = np.log(spectrogram.T+np.finfo(float).eps)
    height = log_spec.shape[1]
    width = log_spec.shape[0]
    X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
    Y = range(height)
    ax.pcolormesh(X, Y, log_spec.T)

    
fig, axes = plt.subplots(2, figsize=(12, 12))
timescale = np.arange(waveform.shape[0])
axes[0].set_xlabel('Номер отсчета')
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Аудиосигнал')
axes[0].set_xlim([0, waveform.shape[0]])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Спектрограмма')
axes[1].set_xlabel('Номер отсчета')
axes[1].set_ylabel('Номер спектрограммы')
plt.show()
# Out:
# C:\Users\belas\AppData\Local\Temp/ipykernel_16568/3717967252.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(X, Y, log_spec.T)

# %%
def get_spectrogram_and_label_id(audio, label):
    spectrogram = get_spectrogram(audio)
    label_id = tf.argmax(label == notes)
    return spectrogram, label_id

def get_spectrogram_and_label_id_15(spectrogram, label_id):
    spec_length = len(spectrogram)
    if spec_length<15:
        for k in range(15-spec_length):
            spect_last = spectrogram[spec_length-1]
            spect_last = tf.expand_dims(spect_last, 0)
            spectrogram = tf.concat([spectrogram, spect_last], 0)
    elif spec_length>15:
        spectrogram = spectrogram[0:15]

    return spectrogram, label_id

# %%
spectrogram_ds = waveform_ds.map(map_func=get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)

spectrogram_ds = spectrogram_ds.map(lambda x, y: get_spectrogram_and_label_id_15(x,y))

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(18, 18))
for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
    r = i // cols
    c = i % cols
    
    plot_spectrogram(np.squeeze(spectrogram.numpy()), axes[r][c])
    axes[r][c].set_title(notes[label_id.numpy()])
    axes[r][c].set_xlabel('Номер отсчета')
    axes[r][c].set_ylabel('Номер спектрограммы')


plt.show()
# Out:
# C:\Users\belas\AppData\Local\Temp/ipykernel_16568/3717967252.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(X, Y, log_spec.T)

# %%
def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(map_func=get_waveform_and_label, num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.map(map_func=get_spectrogram_and_label_id,  num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.filter(without_zero_len) # Удаляем сигналы нулевой длины
    output_ds = output_ds.map(lambda x, y: get_spectrogram_and_label_id_15(x,y))
    return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)
print('Фактические длины датасетов: ')
dataset_length = [i for i,_ in enumerate(train_ds)][-1] + 1
print('train_ds:', dataset_length)
dataset_length = [i for i,_ in enumerate(val_ds)][-1] + 1
print('val_ds:', dataset_length)
dataset_length = [i for i,_ in enumerate(test_ds)][-1] + 1
print('test_ds: ', dataset_length)
# Out:
# Фактические длины датасетов:
# train_ds: 19590
# val_ds: 5595
# test_ds:  2797

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
print('Input shape:', input_shape)

def create_model():
    inputs = layers.Input(shape = input_shape, name = "inputs")
    x = layers.Flatten()(inputs)
    x = layers.Dense(512,activation = 'relu', name = "relu_1")(x)
    x = layers.Dense(512,activation = 'relu', name = "relu_2")(x)
    x = layers.Dense(512,activation = 'relu', name = "relu_3")(x)
    outputs = layers.Dense(12,activation = 'softmax', name = "dense_end")(x)
    model = tf.keras.Model(inputs = inputs, outputs = outputs)
    model.compile(optimizer='adam',
                  loss = 'sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model
    

model = create_model()
model.summary()
# Out:
# Input shape: (15, 1025)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 15, 1025)]        0
#
#  flatten_1 (Flatten)         (None, 15375)             0
#
#  relu_1 (Dense)              (None, 512)               7872512
#
#  relu_2 (Dense)              (None, 512)               262656
#
#  relu_3 (Dense)              (None, 512)               262656
#
#  dense_end (Dense)           (None, 12)                6156
#
# =================================================================
# Total params: 8,403,980
# Trainable params: 8,403,980
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
history = model.fit(
    train_ds, 
    validation_data=val_ds,  
    epochs=EPOCHS,
    #callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/100
# 307/307 [==============================] - 13s 43ms/step - loss: 0.4224 - accuracy: 0.9094 - val_loss: 0.3326 - val_accuracy: 0.9237
# Epoch 2/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.2414 - accuracy: 0.9435 - val_loss: 0.2902 - val_accuracy: 0.9358
# Epoch 3/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.1995 - accuracy: 0.9542 - val_loss: 0.3046 - val_accuracy: 0.9421
# Epoch 4/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.1451 - accuracy: 0.9625 - val_loss: 0.3338 - val_accuracy: 0.9419
# Epoch 5/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.1297 - accuracy: 0.9678 - val_loss: 0.3284 - val_accuracy: 0.9432
# Epoch 6/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.1176 - accuracy: 0.9712 - val_loss: 0.3548 - val_accuracy: 0.9417
# Epoch 7/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0886 - accuracy: 0.9764 - val_loss: 0.3807 - val_accuracy: 0.9421
# Epoch 8/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0891 - accuracy: 0.9781 - val_loss: 0.4988 - val_accuracy: 0.9471
# Epoch 9/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0735 - accuracy: 0.9806 - val_loss: 0.4071 - val_accuracy: 0.9416
# Epoch 10/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0685 - accuracy: 0.9826 - val_loss: 0.3829 - val_accuracy: 0.9394
# Epoch 11/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0665 - accuracy: 0.9826 - val_loss: 0.3983 - val_accuracy: 0.9378
# Epoch 12/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0639 - accuracy: 0.9840 - val_loss: 0.4350 - val_accuracy: 0.9451
# Epoch 13/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0445 - accuracy: 0.9874 - val_loss: 0.4813 - val_accuracy: 0.9464
# Epoch 14/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0517 - accuracy: 0.9876 - val_loss: 0.5103 - val_accuracy: 0.9448
# Epoch 15/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0559 - accuracy: 0.9865 - val_loss: 0.5292 - val_accuracy: 0.9485
# Epoch 16/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0470 - accuracy: 0.9888 - val_loss: 0.5599 - val_accuracy: 0.9394
# Epoch 17/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0546 - accuracy: 0.9862 - val_loss: 0.5591 - val_accuracy: 0.9480
# Epoch 18/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0377 - accuracy: 0.9908 - val_loss: 0.5252 - val_accuracy: 0.9464
# Epoch 19/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0419 - accuracy: 0.9906 - val_loss: 0.5968 - val_accuracy: 0.9516
# Epoch 20/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0339 - accuracy: 0.9931 - val_loss: 0.6031 - val_accuracy: 0.9530
# Epoch 21/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0284 - accuracy: 0.9943 - val_loss: 0.5836 - val_accuracy: 0.9453
# Epoch 22/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0329 - accuracy: 0.9919 - val_loss: 0.5540 - val_accuracy: 0.9451
# Epoch 23/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0417 - accuracy: 0.9900 - val_loss: 0.5609 - val_accuracy: 0.9476
# Epoch 24/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0268 - accuracy: 0.9935 - val_loss: 0.6746 - val_accuracy: 0.9408
# Epoch 25/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0342 - accuracy: 0.9933 - val_loss: 0.6455 - val_accuracy: 0.9491
# Epoch 26/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0448 - accuracy: 0.9930 - val_loss: 0.4843 - val_accuracy: 0.9467
# Epoch 27/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0298 - accuracy: 0.9937 - val_loss: 0.6397 - val_accuracy: 0.9482
# Epoch 28/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0203 - accuracy: 0.9960 - val_loss: 0.6312 - val_accuracy: 0.9546
# Epoch 29/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0202 - accuracy: 0.9955 - val_loss: 0.7602 - val_accuracy: 0.9489
# Epoch 30/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0402 - accuracy: 0.9920 - val_loss: 0.6317 - val_accuracy: 0.9458
# Epoch 31/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0541 - accuracy: 0.9905 - val_loss: 0.6366 - val_accuracy: 0.9433
# Epoch 32/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0195 - accuracy: 0.9953 - val_loss: 0.5982 - val_accuracy: 0.9510
# Epoch 33/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0355 - accuracy: 0.9917 - val_loss: 0.6941 - val_accuracy: 0.9469
# Epoch 34/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0306 - accuracy: 0.9945 - val_loss: 0.6714 - val_accuracy: 0.9501
# Epoch 35/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.6768 - val_accuracy: 0.9498
# Epoch 36/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 0.6303 - val_accuracy: 0.9433
# Epoch 37/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0287 - accuracy: 0.9938 - val_loss: 0.7228 - val_accuracy: 0.9500
# Epoch 38/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0279 - accuracy: 0.9947 - val_loss: 0.9796 - val_accuracy: 0.9507
# Epoch 39/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0675 - accuracy: 0.9913 - val_loss: 0.6450 - val_accuracy: 0.9450
# Epoch 40/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0301 - accuracy: 0.9952 - val_loss: 0.7142 - val_accuracy: 0.9487
# Epoch 41/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0453 - accuracy: 0.9940 - val_loss: 0.7095 - val_accuracy: 0.9469
# Epoch 42/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0649 - accuracy: 0.9956 - val_loss: 0.6814 - val_accuracy: 0.9526
# Epoch 43/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0119 - accuracy: 0.9980 - val_loss: 0.8407 - val_accuracy: 0.9516
# Epoch 44/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0226 - accuracy: 0.9965 - val_loss: 0.7559 - val_accuracy: 0.9516
# Epoch 45/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0276 - accuracy: 0.9946 - val_loss: 0.7698 - val_accuracy: 0.9510
# Epoch 46/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0486 - accuracy: 0.9933 - val_loss: 0.6906 - val_accuracy: 0.9498
# Epoch 47/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0289 - accuracy: 0.9950 - val_loss: 0.7122 - val_accuracy: 0.9519
# Epoch 48/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0247 - accuracy: 0.9948 - val_loss: 0.7381 - val_accuracy: 0.9500
# Epoch 49/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0296 - accuracy: 0.9947 - val_loss: 0.5815 - val_accuracy: 0.9517
# Epoch 50/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0323 - accuracy: 0.9952 - val_loss: 0.7441 - val_accuracy: 0.9523
# Epoch 51/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0174 - accuracy: 0.9974 - val_loss: 0.6880 - val_accuracy: 0.9521
# Epoch 52/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 0.7535 - val_accuracy: 0.9535
# Epoch 53/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.7441 - val_accuracy: 0.9541
# Epoch 54/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0288 - accuracy: 0.9954 - val_loss: 0.8145 - val_accuracy: 0.9473
# Epoch 55/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.9149 - val_accuracy: 0.9514
# Epoch 56/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0556 - accuracy: 0.9927 - val_loss: 0.7977 - val_accuracy: 0.9514
# Epoch 57/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0298 - accuracy: 0.9955 - val_loss: 0.8744 - val_accuracy: 0.9512
# Epoch 58/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0336 - accuracy: 0.9955 - val_loss: 0.8756 - val_accuracy: 0.9505
# Epoch 59/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0321 - accuracy: 0.9948 - val_loss: 0.8050 - val_accuracy: 0.9546
# Epoch 60/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0108 - accuracy: 0.9980 - val_loss: 1.0430 - val_accuracy: 0.9544
# Epoch 61/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0147 - accuracy: 0.9969 - val_loss: 0.9859 - val_accuracy: 0.9535
# Epoch 62/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0289 - accuracy: 0.9969 - val_loss: 1.0259 - val_accuracy: 0.9526
# Epoch 63/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0249 - accuracy: 0.9974 - val_loss: 0.9179 - val_accuracy: 0.9523
# Epoch 64/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0130 - accuracy: 0.9979 - val_loss: 0.9736 - val_accuracy: 0.9553
# Epoch 65/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0156 - accuracy: 0.9981 - val_loss: 1.0761 - val_accuracy: 0.9534
# Epoch 66/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0144 - accuracy: 0.9983 - val_loss: 1.2365 - val_accuracy: 0.9476
# Epoch 67/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0594 - accuracy: 0.9940 - val_loss: 0.9931 - val_accuracy: 0.9471
# Epoch 68/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0403 - accuracy: 0.9936 - val_loss: 1.0206 - val_accuracy: 0.9534
# Epoch 69/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0266 - accuracy: 0.9956 - val_loss: 1.0132 - val_accuracy: 0.9473
# Epoch 70/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0327 - accuracy: 0.9955 - val_loss: 1.1717 - val_accuracy: 0.9487
# Epoch 71/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0230 - accuracy: 0.9967 - val_loss: 0.9219 - val_accuracy: 0.9466
# Epoch 72/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0138 - accuracy: 0.9975 - val_loss: 1.0192 - val_accuracy: 0.9546
# Epoch 73/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0751 - accuracy: 0.9977 - val_loss: 0.9979 - val_accuracy: 0.9483
# Epoch 74/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0178 - accuracy: 0.9978 - val_loss: 1.0665 - val_accuracy: 0.9530
# Epoch 75/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0307 - accuracy: 0.9967 - val_loss: 0.9792 - val_accuracy: 0.9475
# Epoch 76/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0291 - accuracy: 0.9952 - val_loss: 1.1937 - val_accuracy: 0.9507
# Epoch 77/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0241 - accuracy: 0.9957 - val_loss: 1.3161 - val_accuracy: 0.9442
# Epoch 78/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0308 - accuracy: 0.9941 - val_loss: 1.1731 - val_accuracy: 0.9505
# Epoch 79/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 1.3035 - val_accuracy: 0.9548
# Epoch 80/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0323 - accuracy: 0.9948 - val_loss: 1.0344 - val_accuracy: 0.9475
# Epoch 81/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 1.2152 - val_accuracy: 0.9535
# Epoch 82/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0205 - accuracy: 0.9974 - val_loss: 1.0789 - val_accuracy: 0.9510
# Epoch 83/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 1.0870 - val_accuracy: 0.9516
# Epoch 84/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0109 - accuracy: 0.9981 - val_loss: 1.2263 - val_accuracy: 0.9508
# Epoch 85/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 1.1991 - val_accuracy: 0.9535
# Epoch 86/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0200 - accuracy: 0.9968 - val_loss: 1.3516 - val_accuracy: 0.9492
# Epoch 87/100
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0240 - accuracy: 0.9955 - val_loss: 1.1381 - val_accuracy: 0.9453
# Epoch 88/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0283 - accuracy: 0.9953 - val_loss: 0.9698 - val_accuracy: 0.9500
# Epoch 89/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 1.1295 - val_accuracy: 0.9467
# Epoch 90/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0124 - accuracy: 0.9969 - val_loss: 1.0449 - val_accuracy: 0.9455
# Epoch 91/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0096 - accuracy: 0.9980 - val_loss: 1.2366 - val_accuracy: 0.9546
# Epoch 92/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0159 - accuracy: 0.9967 - val_loss: 1.4965 - val_accuracy: 0.9494
# Epoch 93/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0398 - accuracy: 0.9948 - val_loss: 0.9405 - val_accuracy: 0.9525
# Epoch 94/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0182 - accuracy: 0.9966 - val_loss: 1.5161 - val_accuracy: 0.9469
# Epoch 95/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0126 - accuracy: 0.9973 - val_loss: 1.3022 - val_accuracy: 0.9521
# Epoch 96/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0785 - accuracy: 0.9888 - val_loss: 0.8853 - val_accuracy: 0.9464
# Epoch 97/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.0298 - accuracy: 0.9954 - val_loss: 1.1100 - val_accuracy: 0.9446
# Epoch 98/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0141 - accuracy: 0.9969 - val_loss: 1.3035 - val_accuracy: 0.9476
# Epoch 99/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0222 - accuracy: 0.9973 - val_loss: 1.4269 - val_accuracy: 0.9473
# Epoch 100/100
# 307/307 [==============================] - 8s 24ms/step - loss: 0.0196 - accuracy: 0.9969 - val_loss: 1.2523 - val_accuracy: 0.9507

# %%
metrics = history.history

fig, axes = plt.subplots(2, 1, figsize=(6, 6), constrained_layout=True)
axes[0].plot(history.epoch, metrics['loss'], metrics['val_loss'])
axes[0].legend(['loss', 'val_loss'])
axes[0].set(xlabel='Номер эпохи', ylabel='Функция штрафа', title=f'Штраф тренировочный/проверочный')

axes[1].plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
axes[1].legend(['accuracy', 'val_accuracy'])
axes[1].set(xlabel='Номер эпохи', ylabel='Точность', title=f'Точность тренировочная/проверочная')
# Out:
# [Text(0.5, 0, 'Номер эпохи'),
#  Text(0, 0.5, 'Точность'),
#  Text(0.5, 1.0, 'Точность тренировочная/проверочная')]

# %%
test_audio = []
test_labels = []

count = 0
for audio, label in test_ds:
    test_audio.append(audio.numpy())
    test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true) * 100
print('Test set accuracy: ', test_acc, '%')
# Out:
# Test set accuracy:  95.28065784769396 %

# %%
p = model.predict(test_audio)
for idx, pp in enumerate(p[:3]):
    plt.bar(np.arange(0,12),pp, label = y_true[idx])

plt.xlabel('Значение')
plt.ylabel('Вероятность')
plt.title('Предсказание')
plt.xticks(np.arange(0,12)) # ['A' 'A#' 'B' 'C' 'C#' 'D' 'D#' 'E' 'F' 'F#' 'G' 'G#']
plt.legend()

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred) 
plt.figure(figsize=(8, 10))
sns.heatmap(confusion_mtx, xticklabels=notes, yticklabels=notes, 
            annot=True, fmt='g')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.title('Матрица ошибок')
plt.show()

# %%
sample_file = data_dir/'E/arpeg-CMaj-060BPM-leg_2.wav'
print('Sample file:', filenames[0])

sample_ds = preprocess_dataset([str(sample_file)])

for spectrogram, label in sample_ds.batch(1):
    prediction = model(spectrogram)
    plt.bar(notes, prediction[0])
    t = 'Predictions for "'+ notes[label[0]]+'"'
    plt.title(t)
    plt.show()
# Out:
# Sample file: tf.Tensor(b'D:\\magistracy\\diplom\\records_cut\\D#\\en027a_55.wav', shape=(), dtype=string)

# %%
# Сохраняем модель
model.save(r"D:\magistracy\diplom\model\model.h5")
